# %% [markdown]
# <a href="https://colab.research.google.com/github/seungmindavid/Machine-Learning-2023/blob/main/LSH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Locality Sensitive Hashing - Random Projection
#
# ![Screenshot 2023-11-03 at 6.33.53 PM.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
#df
x_train = df['x_train']
y_train = df['y_train']


L = 3 # Number of hyperplane
d = 2 # 2d vector
u = np.random.rand(L, d) - 0.5 # Random unit vector

buckets = {}

for i, x in enumerate(x_train):
  proj_x = np.dot(x, u.T)
  proj_x = (proj_x > 0).astype(int)
  hash_str = ''.join(proj_x.astype(str))
  if hash_str not in buckets.keys():
    buckets[hash_str] = []
  buckets[hash_str].append(i)

for b in buckets:
  print(b,':', buckets[b])
  print('\n')
# Out:
# 001 : [0, 4, 20, 31, 33, 41, 47, 50, 53, 54, 62, 71, 77, 81, 93, 100, 102, 105, 115, 117, 123, 128, 141, 143, 149, 150, 153, 157, 160, 161, 165, 169, 170, 175, 183, 188, 192, 195, 200, 205, 213, 225, 228, 232, 234, 249, 250, 255, 256, 257, 259, 267, 269, 278, 279, 287, 290, 292, 294, 306, 307, 312, 315, 316, 321, 326, 328, 334, 346, 347, 352, 363, 372, 398, 401, 402, 409, 410, 411, 412, 423, 427, 432, 440, 442, 445, 449, 458, 459, 465, 467, 474, 476, 481, 482, 485, 488, 491, 499, 508, 512, 515, 517, 518, 519, 523, 529, 535, 539, 545, 547, 555, 558, 570, 571, 577, 588, 593, 598, 609, 611, 614, 619, 620, 624, 626, 627, 628, 630, 639, 642, 644, 647, 650, 654, 657, 665, 666, 675, 676, 697, 699, 700, 704, 712, 718, 729, 735, 743, 744, 746, 749, 756, 765, 769, 784, 798, 810, 814, 815, 817, 819, 830, 836, 837, 860, 872, 875, 877, 880, 883, 885, 887, 888, 891, 901, 912, 915, 917, 920, 927, 933, 934, 936, 937, 942, 947, 952, 955, 956, 964, 965, 976, 982, 989, 991, 992, 997, 1005, 1010, 1013, 
# ...

# %%
import matplotlib.pyplot as plt

# Extract the x and y values
x = x_train[:, 0]
y = x_train[:, 1]

# Create a scatter plot
plt.scatter(x, y, marker='o', s=10)  # You can adjust the marker style and size as needed
for r in u:
  slope, intercept = r
  x_line = np.linspace(-1,1,100)
  y_line = slope* x_line + intercept
  plt.plot(x_line, y_line, 'red', linestyle="-")
# Add labels and a title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plot
plt.show()
